# %% [markdown]
# ### Used Car prices in India

# %% [markdown]
# #### Importing relevant libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
from pandas import Series, DataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### Reading the dataset into Python Environment

# %%
dataset = pd.read_csv('cardekho_updated.csv')
dataset.head(5)
# Out:
#                                         full_name selling_price  \
# 0                                 Maruti Alto Std     1.2 Lakh*
# 1                          Hyundai Grand i10 Asta     5.5 Lakh*
# 2                                Hyundai i20 Asta    2.15 Lakh*
# 3                   Maruti Alto K10 2010-2014 VXI    2.26 Lakh*
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV     5.7 Lakh*
#
#                                         new_price  year seller_type  \
# 0                                             NaN  2012  Individual
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016  Individual
# 2                                             NaN  2010  Individual
# 3                                             NaN  2012  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015      Dealer
#
#       km_driven   owner_type fuel_type transmission_type            mileage  \
# 0  1,20,000 kms  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1    20,000 kms  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2    60,000 kms  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3    37,000 kms  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4    30,000 kms  First Owner    Diesel            Manual  Mileage22.77 kmpl
#
#           engine           max_power   seats
# 0   Engine796 CC   Max Power46.3 bhp  Seats5
# 1  Engine1197 CC     Max Power82 bhp  Seats5
# 2  Engine1197 CC     Max Power80 bhp  Seats5
# 3   Engine998 CC   Max Power67.1 bhp  Seats5
# 4  Engine1498 CC  Max Power98.59 bhp  Seats5

# %%
dataset.tail(2)
# Out:
#                       full_name selling_price  \
# 19972    Mahindra XUV500 W6 2WD   12.25 Lakh*
# 19973  Honda City i-VTEC CVT VX      12 Lakh*
#
#                                             new_price  year seller_type  \
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016      Dealer
# 19973                                             NaN  2019      Dealer
#
#            km_driven   owner_type fuel_type transmission_type  \
# 19972  38,00,000 kms  First Owner    Diesel            Manual
# 19973     13,000 kms  First Owner    Petrol         Automatic
#
#                 mileage         engine           max_power   seats
# 19972  Mileage16.0 kmpl  Engine2179 CC    Max Power140 bhp  Seats7
# 19973  Mileage18.0 kmpl  Engine1497 CC  Max Power117.6 bhp  Seats5

# %% [markdown]
# #### 2. Checking the basic details of the dataset:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19974 entries, 0 to 19973
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19974 non-null  object
#  1   selling_price      19974 non-null  object
#  2   new_price          9564 non-null   object
#  3   year               19974 non-null  int64
#  4   seller_type        19974 non-null  object
#  5   km_driven          19974 non-null  object
#  6   owner_type         19974 non-null  object
#  7   fuel_type          19974 non-null  object
#  8   transmission_type  19974 non-null  object
#  9   mileage            19814 non-null  object
#  10  engine             19864 non-null  object
#  11  max_power          19637 non-null  object
#  12  seats              19887 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.0+ MB

# %%
dataset.describe(include = 'all')
# Out:
#                      full_name selling_price  \
# count                    19974         19974
# unique                    3321          1215
# top     Maruti Swift Dzire VDI     4.5 Lakh*
# freq                       210           466
# mean                       NaN           NaN
# std                        NaN           NaN
# min                        NaN           NaN
# 25%                        NaN           NaN
# 50%                        NaN           NaN
# 75%                        NaN           NaN
# max                        NaN           NaN
#
#                                              new_price          year  \
# count                                             9564  19974.000000
# unique                                            1744           NaN
# top     New Car (On-Road Price) : Rs.12.68-16.80 Lakh*           NaN
# freq                                               144           NaN
# mean                                               NaN   2014.526134
# std                                                NaN      3.248791
# min                                                NaN   1991.000000
# 25%                                                NaN   2013.000000
# 50%                                                NaN   2015.000000
# 75%                                                NaN   2017.000000
# max                                                NaN   2021.000000
#
#        seller_type   km_driven   owner_type fuel_type transmission_type  \
# count        19974       19974        19974     19974             19974
# unique           3        4515            1         5                 2
# top         Dealer  50,000 kms  First Owner    Diesel            Manual
# freq         11970         750        19974      9815             16025
# mean           NaN         NaN          NaN       NaN               NaN
# std            NaN         NaN          NaN       NaN               NaN
# min            NaN         NaN          NaN       NaN               NaN
# 25%            NaN         NaN          NaN       NaN               NaN
# 50%            NaN         NaN          NaN       NaN               NaN
# 75%            NaN         NaN          NaN       NaN               NaN
# max            NaN         NaN          NaN       NaN               NaN
#
#                  mileage         engine        max_power   seats
# count              19814          19864            19637   19887
# unique               561            169              493       9
# top     Mileage18.9 kmpl  Engine1197 CC  Max Power74 bhp  Seats5
# freq                 624           2662              867   16585
# mean                 NaN            NaN              NaN     NaN
# std                  NaN            NaN              NaN     NaN
# min                  NaN            NaN              NaN     NaN
# 25%                  NaN            NaN              NaN     NaN
# 50%                  NaN            NaN              NaN     NaN
# 75%                  NaN            NaN              NaN     NaN
# max                  NaN            NaN              NaN     NaN

# %%
dataset.columns
# Out:
# Index(['full_name', 'selling_price', 'new_price', 'year', 'seller_type',
#        'km_driven', 'owner_type', 'fuel_type', 'transmission_type', 'mileage',
#        'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (19974, 13)

# %%
dataset['full_name'].unique()
# Out:
# array(['Maruti Alto Std', 'Hyundai Grand i10 Asta', 'Hyundai i20 Asta',
#        ..., 'Tata Safari 2005-2017 DICOR 2.2 GX 4x2',
#        'Ford Ecosport 2015-2021 Signature Edition Petrol BSIV',
#        'Toyota Yaris V Optional CVT BSIV'], dtype=object)

# %% [markdown]
# #### Insights:
#           There are 19974 rows and 13 columns/features of different datatypes present in the dataset.

# %% [markdown]
# #### 3. Checking the missing values in the dataset

# %%
dataset.isna().sum()
# Out:
# full_name                0
# selling_price            0
# new_price            10410
# year                     0
# seller_type              0
# km_driven                0
# owner_type               0
# fuel_type                0
# transmission_type        0
# mileage                160
# engine                 110
# max_power              337
# seats                   87
# dtype: int64

# %% [markdown]
# #### Insights:
#         There are missing values in the features of new_price, mileage, engine, max_power and seats.

# %% [markdown]
# ## Preprocessing steps to be taken:

# %%
dataset.dtypes
# Out:
# full_name            object
# selling_price        object
# new_price            object
# year                  int64
# seller_type          object
# km_driven            object
# owner_type           object
# fuel_type            object
# transmission_type    object
# mileage              object
# engine               object
# max_power            object
# seats                object
# dtype: object

# %% [markdown]
# ### 1. Filling the missing values in the dataset.

# %%
obj_cols = list(dataset.select_dtypes('object').columns)
for o in obj_cols:
    dataset[o].fillna("NULL",inplace = True)

# %%
dataset.isna().sum()
# Out:
# full_name            0
# selling_price        0
# new_price            0
# year                 0
# seller_type          0
# km_driven            0
# owner_type           0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# dtype: int64

# %% [markdown]
# #### Insights:
#            There are no more missing values in the dataset after filing the missing values.

# %% [markdown]
# ### 2. Outlier Detection and Handling:

# %% [markdown]
# ##### a. Checking the Outliers in the dataset:

# %% [markdown]
# Inorder to check the outliers, we need to plot boxplot of the features using percentiles.

# %%
plt.figure(figsize=(10,5))
dataset.boxplot()
plt.xticks(rotation=90)
# Out:
# (array([1]), [Text(1, 0, 'year')])

# %%
dataset.corr()
# Out:
#       year
# year   1.0

# %% [markdown]
# #### b. Handling the outliers in  'year'  :

# %%
Q1=np.percentile(dataset['year'], 25, interpolation = 'midpoint')
Q2=np.percentile(dataset['year'], 50, interpolation = 'midpoint')
Q3=np.percentile(dataset['year'], 75, interpolation = 'midpoint')
print("Q1 is : ", Q1)
print("Q2 is : ",Q2)
print("Q3 is : ",Q3)
# Out:
# Q1 is :  2013.0
# Q2 is :  2015.0
# Q3 is :  2017.0

# %%
dataset['year'].median()
# Out:
# 2015.0

# %%
IQR= Q3 - Q1
low_lim = Q1 - 1.5* IQR
up_lim = Q3 + 1.5 * IQR


print("IQR is : ",IQR)
print("Lower Limit is :",round(low_lim))
print("Upper limit is: ",round(up_lim))
# Out:
# IQR is :  4.0
# Lower Limit is : 2007
# Upper limit is:  2023

# %%
##dataset[(dataset['year'] > 2023) ^ (dataset['year'] < 2007)]

# %%
outlier=[]
for x in dataset['year']:
    if((x>up_lim) or(x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [2004,
#  2006,
#  2006,
#  2000,
#  2004,
#  2005,
#  2005,
#  2005,
#  2006,
#  2005,
#  2002,
#  2000,
#  2005,
#  2006,
#  2005,
#  2004,
#  1999,
#  2006,
#  2005,
#  2006,
#  2005,
#  2003,
#  1997,
#  2004,
#  2003,
#  2005,
#  2003,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2005,
#  2003,
#  2006,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2005,
#  1999,
#  2006,
#  2002,
#  2000,
#  1999,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2001,
#  1999,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2006,
#  2006,
#  2006,
#  1992,
#  2006,
#  2001,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2002,
#  2006,
#  2004,
#  2003,
#  2006,
#  2005,
#  2004,
#  2003,
#  2006,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2002,
#  2004,
#  2004,
#  2005,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  2000,
#  2004,
#  2006,
#  2005,
#  2006,
#  2000,
#  2002,
#  1999,
#  1999,
#  2005,
#  2002,
#  2003,
#  2003,
#  2006,
#  2005,
#  2005,
#  2005,
#  2003,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  1999,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2003,
#  2006,
#  2006,
#  2001,
#  2005,
#  2004,
#  2004,
#  2004,
#  2006,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2004,
#  2005,
#  2000,
#  2006,
#  2005,
#  2006,
#  2003,
#  1999,
#  2006,
#  2004,
#  2003,
#  2005,
#  2001,
#  2006,
#  2003,
#  2005,
#  1998,
#  2005,
#  2006,
#  2004,
#  2004,
#  2004,
#  2000,
#  2001,
#  1998,
#  2006,
#  2006,
#  2006,
#  1999,
#  2002,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2006,
#  2005,
#  1998,
#  2004,
#  2006,
#  2006,
#  2003,
#  2004,
#  2006,
#  2006,
#  1998,
#  2006,
#  2005,
#  2006,
#  2005,
#  2006,
#  2006,
#  2002,
#  2001,
#  2006,
#  2006,
#  2004,
#  1999,
#  2000,
#  2006,
#  2006,
#  2002,
#  2006,
#  2006,
#  2004,
#  2005,
#  2003,
#  2005,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2000,
#  2002,
#  2005,
#  2004,
#  2005,
#  2006,
#  2005,
#  2001,
#  2003,
#  2006,
#  2006,
#  2006,
#  2005,
#  2003,
#  2005,
#  2005,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  1998,
#  2003,
#  2006,
#  2006,
#  2004,
#  2005,
#  2006,
#  2004,
#  2001,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2004,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2002,
#  2004,
#  2000,
#  2006,
#  2004,
#  2006,
#  2001,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  1999,
#  2004,
#  2006,
#  2006,
#  2005,
#  2001,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  1999,
#  2006,
#  1991,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2004,
#  1998,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  1996]

# %%
dataset['year']=np.where(dataset['year']>up_lim,up_lim,np.where(dataset['year']<low_lim,low_lim,dataset['year']))
dataset
# Out:
#                                             full_name selling_price  \
# 0                                     Maruti Alto Std     1.2 Lakh*
# 1                              Hyundai Grand i10 Asta     5.5 Lakh*
# 2                                    Hyundai i20 Asta    2.15 Lakh*
# 3                       Maruti Alto K10 2010-2014 VXI    2.26 Lakh*
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV     5.7 Lakh*
# ...                                               ...           ...
# 19969                   Toyota Platinum Etios 1.4 GXD     6.5 Lakh*
# 19970                          Maruti Ertiga BSIV VXI    9.25 Lakh*
# 19971                    Skoda Rapid 1.5 TDI Elegance    4.25 Lakh*
# 19972                          Mahindra XUV500 W6 2WD   12.25 Lakh*
# 19973                        Honda City i-VTEC CVT VX      12 Lakh*
#
#                                             new_price    year seller_type  \
# 0                                                NULL  2012.0  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 2                                                NULL  2010.0  Individual
# 3                                                NULL  2012.0  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# ...                                               ...     ...         ...
# 19969                                            NULL  2017.0      Dealer
# 19970                                            NULL  2019.0      Dealer
# 19971                                            NULL  2015.0      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016.0      Dealer
# 19973                                            NULL  2019.0      Dealer
#
#            km_driven   owner_type fuel_type transmission_type  \
# 0       1,20,000 kms  First Owner    Petrol            Manual
# 1         20,000 kms  First Owner    Petrol            Manual
# 2         60,000 kms  First Owner    Petrol            Manual
# 3         37,000 kms  First Owner    Petrol            Manual
# 4         30,000 kms  First Owner    Diesel            Manual
# ...              ...          ...       ...               ...
# 19969     69,480 kms  First Owner    Diesel            Manual
# 19970     18,000 kms  First Owner    Petrol            Manual
# 19971     67,000 kms  First Owner    Diesel            Manual
# 19972  38,00,000 kms  First Owner    Diesel            Manual
# 19973     13,000 kms  First Owner    Petrol         Automatic
#
#                  mileage         engine            max_power   seats
# 0       Mileage19.7 kmpl   Engine796 CC    Max Power46.3 bhp  Seats5
# 1       Mileage18.9 kmpl  Engine1197 CC      Max Power82 bhp  Seats5
# 2       Mileage17.0 kmpl  Engine1197 CC      Max Power80 bhp  Seats5
# 3      Mileage20.92 kmpl   Engine998 CC    Max Power67.1 bhp  Seats5
# 4      Mileage22.77 kmpl  Engine1498 CC   Max Power98.59 bhp  Seats5
# ...                  ...            ...                  ...     ...
# 19969  Mileage23.59 kmpl  Engine1364 CC   Max Power67.05 bhp  Seats5
# 19970   Mileage17.5 kmpl  Engine1373 CC    Max Power91.1 bhp  Seats7
# 19971  Mileage21.14 kmpl  Engine1498 CC  Max Power103.52 bhp  Seats5
# 19972   Mileage16.0 kmpl  Engine2179 CC     Max Power140 bhp  Seats7
# 19973   Mileage18.0 kmpl  Engine1497 CC   Max Power117.6 bhp  Seats5
#
# [19974 rows x 13 columns]

# %%
plt.figure(figsize=(10,5))
dataset.boxplot()
plt.xticks(rotation=60)
plt.title('Box plot of year')
# Out:
# Text(0.5, 1.0, 'Box plot of year')

# %% [markdown]
# ####  Outlier has been detected in 'year' and it has been handled using percentiles.

# %% [markdown]
# #### Creating a new feature named "Company" by replacing "full_name"

# %%
#dataset.rename(columns={'full_name': 'Company'}, inplace = True )
#dataset.head(5)

dataset['Company'] = dataset['full_name'].str.split(' ', expand=True)[0]

dataset['brand']=dataset.full_name.str.split(' ').str.get(1)
dataset
# Out:
#                                             full_name selling_price  \
# 0                                     Maruti Alto Std     1.2 Lakh*
# 1                              Hyundai Grand i10 Asta     5.5 Lakh*
# 2                                    Hyundai i20 Asta    2.15 Lakh*
# 3                       Maruti Alto K10 2010-2014 VXI    2.26 Lakh*
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV     5.7 Lakh*
# ...                                               ...           ...
# 19969                   Toyota Platinum Etios 1.4 GXD     6.5 Lakh*
# 19970                          Maruti Ertiga BSIV VXI    9.25 Lakh*
# 19971                    Skoda Rapid 1.5 TDI Elegance    4.25 Lakh*
# 19972                          Mahindra XUV500 W6 2WD   12.25 Lakh*
# 19973                        Honda City i-VTEC CVT VX      12 Lakh*
#
#                                             new_price    year seller_type  \
# 0                                                NULL  2012.0  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 2                                                NULL  2010.0  Individual
# 3                                                NULL  2012.0  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# ...                                               ...     ...         ...
# 19969                                            NULL  2017.0      Dealer
# 19970                                            NULL  2019.0      Dealer
# 19971                                            NULL  2015.0      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016.0      Dealer
# 19973                                            NULL  2019.0      Dealer
#
#            km_driven   owner_type fuel_type transmission_type  \
# 0       1,20,000 kms  First Owner    Petrol            Manual
# 1         20,000 kms  First Owner    Petrol            Manual
# 2         60,000 kms  First Owner    Petrol            Manual
# 3         37,000 kms  First Owner    Petrol            Manual
# 4         30,000 kms  First Owner    Diesel            Manual
# ...              ...          ...       ...               ...
# 19969     69,480 kms  First Owner    Diesel            Manual
# 19970     18,000 kms  First Owner    Petrol            Manual
# 19971     67,000 kms  First Owner    Diesel            Manual
# 19972  38,00,000 kms  First Owner    Diesel            Manual
# 19973     13,000 kms  First Owner    Petrol         Automatic
#
#                  mileage         engine            max_power   seats  \
# 0       Mileage19.7 kmpl   Engine796 CC    Max Power46.3 bhp  Seats5
# 1       Mileage18.9 kmpl  Engine1197 CC      Max Power82 bhp  Seats5
# 2       Mileage17.0 kmpl  Engine1197 CC      Max Power80 bhp  Seats5
# 3      Mileage20.92 kmpl   Engine998 CC    Max Power67.1 bhp  Seats5
# 4      Mileage22.77 kmpl  Engine1498 CC   Max Power98.59 bhp  Seats5
# ...                  ...            ...                  ...     ...
# 19969  Mileage23.59 kmpl  Engine1364 CC   Max Power67.05 bhp  Seats5
# 19970   Mileage17.5 kmpl  Engine1373 CC    Max Power91.1 bhp  Seats7
# 19971  Mileage21.14 kmpl  Engine1498 CC  Max Power103.52 bhp  Seats5
# 19972   Mileage16.0 kmpl  Engine2179 CC     Max Power140 bhp  Seats7
# 19973   Mileage18.0 kmpl  Engine1497 CC   Max Power117.6 bhp  Seats5
#
#         Company     brand
# 0        Maruti      Alto
# 1       Hyundai     Grand
# 2       Hyundai       i20
# 3        Maruti      Alto
# 4          Ford  Ecosport
# ...         ...       ...
# 19969    Toyota  Platinum
# 19970    Maruti    Ertiga
# 19971     Skoda     Rapid
# 19972  Mahindra    XUV500
# 19973     Honda      City
#
# [19974 rows x 15 columns]

# %%
dataset.drop(columns=['full_name'], axis=1, inplace=True)

# %% [markdown]
# ##### Creating a new feature vehicle_age from year

# %%
dataset_year=2021
dataset['vehicle_age'] = dataset_year - dataset['year']
dataset.drop(['year'],axis=1, inplace=True)


dataset.head(2)
# Out:
#   selling_price                                     new_price seller_type  \
# 0     1.2 Lakh*                                          NULL  Individual
# 1     5.5 Lakh*  New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  Individual
#
#       km_driven   owner_type fuel_type transmission_type           mileage  \
# 0  1,20,000 kms  First Owner    Petrol            Manual  Mileage19.7 kmpl
# 1    20,000 kms  First Owner    Petrol            Manual  Mileage18.9 kmpl
#
#           engine          max_power   seats  Company  brand  vehicle_age
# 0   Engine796 CC  Max Power46.3 bhp  Seats5   Maruti   Alto          9.0
# 1  Engine1197 CC    Max Power82 bhp  Seats5  Hyundai  Grand          5.0

# %%
col_order=['Company', 'brand','vehicle_age','km_driven','seller_type','fuel_type','transmission_type','mileage','engine','max_power','seats','selling_price']
dataset=dataset[col_order]
dataset.head()
# Out:
#    Company     brand  vehicle_age     km_driven seller_type fuel_type  \
# 0   Maruti      Alto          9.0  1,20,000 kms  Individual    Petrol
# 1  Hyundai     Grand          5.0    20,000 kms  Individual    Petrol
# 2  Hyundai       i20         11.0    60,000 kms  Individual    Petrol
# 3   Maruti      Alto          9.0    37,000 kms  Individual    Petrol
# 4     Ford  Ecosport          6.0    30,000 kms      Dealer    Diesel
#
#   transmission_type            mileage         engine           max_power  \
# 0            Manual   Mileage19.7 kmpl   Engine796 CC   Max Power46.3 bhp
# 1            Manual   Mileage18.9 kmpl  Engine1197 CC     Max Power82 bhp
# 2            Manual   Mileage17.0 kmpl  Engine1197 CC     Max Power80 bhp
# 3            Manual  Mileage20.92 kmpl   Engine998 CC   Max Power67.1 bhp
# 4            Manual  Mileage22.77 kmpl  Engine1498 CC  Max Power98.59 bhp
#
#     seats selling_price
# 0  Seats5     1.2 Lakh*
# 1  Seats5     5.5 Lakh*
# 2  Seats5    2.15 Lakh*
# 3  Seats5    2.26 Lakh*
# 4  Seats5     5.7 Lakh*

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19974 entries, 0 to 19973
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            19974 non-null  object
#  1   brand              19974 non-null  object
#  2   vehicle_age        19974 non-null  float64
#  3   km_driven          19974 non-null  object
#  4   seller_type        19974 non-null  object
#  5   fuel_type          19974 non-null  object
#  6   transmission_type  19974 non-null  object
#  7   mileage            19974 non-null  object
#  8   engine             19974 non-null  object
#  9   max_power          19974 non-null  object
#  10  seats              19974 non-null  object
#  11  selling_price      19974 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 1.8+ MB

# %%
dataset.head(5)
# Out:
#    Company     brand  vehicle_age     km_driven seller_type fuel_type  \
# 0   Maruti      Alto          9.0  1,20,000 kms  Individual    Petrol
# 1  Hyundai     Grand          5.0    20,000 kms  Individual    Petrol
# 2  Hyundai       i20         11.0    60,000 kms  Individual    Petrol
# 3   Maruti      Alto          9.0    37,000 kms  Individual    Petrol
# 4     Ford  Ecosport          6.0    30,000 kms      Dealer    Diesel
#
#   transmission_type            mileage         engine           max_power  \
# 0            Manual   Mileage19.7 kmpl   Engine796 CC   Max Power46.3 bhp
# 1            Manual   Mileage18.9 kmpl  Engine1197 CC     Max Power82 bhp
# 2            Manual   Mileage17.0 kmpl  Engine1197 CC     Max Power80 bhp
# 3            Manual  Mileage20.92 kmpl   Engine998 CC   Max Power67.1 bhp
# 4            Manual  Mileage22.77 kmpl  Engine1498 CC  Max Power98.59 bhp
#
#     seats selling_price
# 0  Seats5     1.2 Lakh*
# 1  Seats5     5.5 Lakh*
# 2  Seats5    2.15 Lakh*
# 3  Seats5    2.26 Lakh*
# 4  Seats5     5.7 Lakh*

# %%
dataset.shape
# Out:
# (19974, 12)

# %% [markdown]
# ### 2. Label Encoding

# %% [markdown]
# ###### Label Encoding
#         Converting the labels into numeric form for the ease of Machine Learning models. Here all the features are of object type, so we need to change those into numerical values using encoding.

# %%
dataset.dtypes
# Out:
# Company               object
# brand                 object
# vehicle_age          float64
# km_driven             object
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# selling_price         object
# dtype: object

# %%
#obj_cols = dataset.select_dtypes(include ='object').columns

#for each in obj_cols:
    #print(dataset[each].value_counts())

# %%
dataset.columns
# Out:
# Index(['Company', 'brand', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
## Loading Label Encoder function

from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

dataset.Company = le.fit_transform(dataset.Company)
dataset.brand = le.fit_transform(dataset.brand)
dataset.selling_price = le.fit_transform(dataset.selling_price)
#dataset.new_price = le.fit_transform(dataset.new_price)
dataset.seller_type = le.fit_transform(dataset.seller_type)
dataset.fuel_type = le.fit_transform(dataset.fuel_type)
dataset.transmission_type = le.fit_transform(dataset.transmission_type)
dataset.engine = le.fit_transform(dataset.engine)
dataset.max_power = le.fit_transform(dataset.max_power)
dataset.seats = le.fit_transform(dataset.seats)
dataset.mileage = le.fit_transform(dataset.mileage)
dataset.km_driven = le.fit_transform(dataset.km_driven)
#dataset.owner_type = le.fit_transform(dataset.owner_type)


dataset
# Out:
#        Company  brand  vehicle_age  km_driven  seller_type  fuel_type  \
# 0           24     20          9.0        167            1          4
# 1           13    113          5.0        874            1          4
# 2           13    271         11.0       3099            1          4
# 3           24     20          9.0       1756            1          4
# 4           11     80          6.0       1383            0          1
# ...        ...    ...          ...        ...          ...        ...
# 19969       39    171          4.0       3561            0          1
# 19970       24     85          2.0        721            0          4
# 19971       37    184          6.0       3448            0          1
# 19972       23    259          5.0       1812            0          1
# 19973       12     61          2.0        538            0          4
#
#        transmission_type  mileage  engine  max_power  seats  selling_price
# 0                      1      359     159        316      5             17
# 1                      1      322      12        424      5            828
# 2                      1      238      12        417      5            348
# 3                      1      404     167        377      5            359
# 4                      1      456      43        482      5            844
# ...                  ...      ...     ...        ...    ...            ...
# 19969                  1      472      23        375      5            942
# 19970                  1      263      25        461      7           1163
# 19971                  1      414      43         14      5            678
# 19972                  1      200      82         96      7            157
# 19973                  0      286      42         51      5            150
#
# [19974 rows x 12 columns]

# %%
dataset.dtypes
# Out:
# Company                int32
# brand                  int32
# vehicle_age          float64
# km_driven              int32
# seller_type            int32
# fuel_type              int32
# transmission_type      int32
# mileage                int32
# engine                 int32
# max_power              int32
# seats                  int32
# selling_price          int32
# dtype: object

# %%
data=pd.DataFrame(dataset.groupby("Company")['selling_price'].median())
data.reset_index()
# Out:
#     Company  selling_price
# 0         0          200.5
# 1         1          303.5
# 2         2          482.0
# 3         3          619.5
# 4         4          380.5
# 5         5          494.5
# 6         6          439.5
# 7         7          503.0
# 8         8          590.0
# 9         9          503.0
# 10       10          906.0
# 11       11          726.0
# 12       12          806.0
# 13       13          692.0
# 14       14          315.0
# 15       15          157.5
# 16       16          486.0
# 17       17          250.0
# 18       18          238.0
# 19       19           42.0
# 20       20          610.0
# 21       21          771.5
# 22       22          287.5
# 23       23          795.0
# 24       24          700.0
# 25       25          980.0
# 26       26          870.0
# 27       27          471.0
# 28       28          436.5
# 29       29          580.0
# 30       30          665.0
# 31       31           43.0
# 32       32           43.0
# 33       33          824.5
# 34       34          384.5
# 35       35          580.0
# 36       36          374.0
# 37       37          692.0
# 38       38          554.0
# 39       39          498.0
# 40       40          787.0
# 41       41          445.0

# %%
data.shape
# Out:
# (42, 1)

# %%
data = dataset.merge(data, on='Company', how='left')
data.head()
# Out:
#    Company  brand  vehicle_age  km_driven  seller_type  fuel_type  \
# 0       24     20          9.0        167            1          4
# 1       13    113          5.0        874            1          4
# 2       13    271         11.0       3099            1          4
# 3       24     20          9.0       1756            1          4
# 4       11     80          6.0       1383            0          1
#
#    transmission_type  mileage  engine  max_power  seats  selling_price_x  \
# 0                  1      359     159        316      5               17
# 1                  1      322      12        424      5              828
# 2                  1      238      12        417      5              348
# 3                  1      404     167        377      5              359
# 4                  1      456      43        482      5              844
#
#    selling_price_y
# 0            700.0
# 1            692.0
# 2            692.0
# 3            700.0
# 4            726.0

# %%
dataset['Annualselling_price']= data['selling_price_y']
dataset.head(3)
# Out:
#    Company  brand  vehicle_age  km_driven  seller_type  fuel_type  \
# 0       24     20          9.0        167            1          4
# 1       13    113          5.0        874            1          4
# 2       13    271         11.0       3099            1          4
#
#    transmission_type  mileage  engine  max_power  seats  selling_price  \
# 0                  1      359     159        316      5             17
# 1                  1      322      12        424      5            828
# 2                  1      238      12        417      5            348
#
#    Annualselling_price
# 0                700.0
# 1                692.0
# 2                692.0

# %%
## Now we have 19974 rows and 14 columns in the dataset after feature engineering. 
dataset.shape
# Out:
# (19974, 13)

# %% [markdown]
# #### Dropping unwanted columns in the dataset:

# %%
dataset.drop(columns=['seller_type'], axis=1, inplace=True)
dataset.head()
# Out:
#    Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0       24     20          9.0        167          4                  1
# 1       13    113          5.0        874          4                  1
# 2       13    271         11.0       3099          4                  1
# 3       24     20          9.0       1756          4                  1
# 4       11     80          6.0       1383          1                  1
#
#    mileage  engine  max_power  seats  selling_price  Annualselling_price
# 0      359     159        316      5             17                700.0
# 1      322      12        424      5            828                692.0
# 2      238      12        417      5            348                692.0
# 3      404     167        377      5            359                700.0
# 4      456      43        482      5            844                726.0

# %%
dataset.describe()
# Out:
#             Company         brand   vehicle_age     km_driven     fuel_type  \
# count  19974.000000  19974.000000  19974.000000  19974.000000  19974.000000
# mean      21.680785    145.048914      6.424001   2221.173075      2.457845
# std       10.593036     84.295911      3.092639   1316.326937      1.517765
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       13.000000     70.000000      4.000000   1120.000000      1.000000
# 50%       24.000000    132.000000      6.000000   2268.000000      1.000000
# 75%       24.000000    218.000000      8.000000   3344.000000      4.000000
# max       41.000000    273.000000     14.000000   4514.000000      4.000000
#
#        transmission_type       mileage        engine     max_power  \
# count       19974.000000  19974.000000  19974.000000  19974.000000
# mean            0.802293    330.059477     58.165365    303.543156
# std             0.398280    137.330829     53.195586    159.669664
# min             0.000000      0.000000      0.000000      0.000000
# 25%             1.000000    238.000000     14.000000    147.000000
# 50%             1.000000    342.000000     42.000000    377.000000
# 75%             1.000000    451.000000     82.000000    424.000000
# max             1.000000    561.000000    169.000000    493.000000
#
#               seats  selling_price  Annualselling_price
# count  19974.000000   19974.000000         19974.000000
# mean       5.284770     641.980475           663.303294
# std        0.896714     317.605501           118.375136
# min        0.000000       0.000000            42.000000
# 25%        5.000000     402.000000           580.000000
# 50%        5.000000     674.000000           700.000000
# 75%        5.000000     906.000000           700.000000
# max        9.000000    1214.000000           980.000000

# %%
dataset.describe().T
# Out:
#                        count         mean          std   min     25%     50%  \
# Company              19974.0    21.680785    10.593036   0.0    13.0    24.0
# brand                19974.0   145.048914    84.295911   0.0    70.0   132.0
# vehicle_age          19974.0     6.424001     3.092639   0.0     4.0     6.0
# km_driven            19974.0  2221.173075  1316.326937   0.0  1120.0  2268.0
# fuel_type            19974.0     2.457845     1.517765   0.0     1.0     1.0
# transmission_type    19974.0     0.802293     0.398280   0.0     1.0     1.0
# mileage              19974.0   330.059477   137.330829   0.0   238.0   342.0
# engine               19974.0    58.165365    53.195586   0.0    14.0    42.0
# max_power            19974.0   303.543156   159.669664   0.0   147.0   377.0
# seats                19974.0     5.284770     0.896714   0.0     5.0     5.0
# selling_price        19974.0   641.980475   317.605501   0.0   402.0   674.0
# Annualselling_price  19974.0   663.303294   118.375136  42.0   580.0   700.0
#
#                         75%     max
# Company                24.0    41.0
# brand                 218.0   273.0
# vehicle_age             8.0    14.0
# km_driven            3344.0  4514.0
# fuel_type               4.0     4.0
# transmission_type       1.0     1.0
# mileage               451.0   561.0
# engine                 82.0   169.0
# max_power             424.0   493.0
# seats                   5.0     9.0
# selling_price         906.0  1214.0
# Annualselling_price   700.0   980.0

# %%
## Prediction Target


dataset['Prediction'] = np.where(data[[ 'km_driven', 'mileage', 'max_power', 'seats', 'engine',
       'transmission_type', 'fuel_type']].sum(axis=1)>dataset['Annualselling_price'], 1, 0)

dataset
# Out:
#        Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0           24     20          9.0        167          4                  1
# 1           13    113          5.0        874          4                  1
# 2           13    271         11.0       3099          4                  1
# 3           24     20          9.0       1756          4                  1
# 4           11     80          6.0       1383          1                  1
# ...        ...    ...          ...        ...        ...                ...
# 19969       39    171          4.0       3561          1                  1
# 19970       24     85          2.0        721          4                  1
# 19971       37    184          6.0       3448          1                  1
# 19972       23    259          5.0       1812          1                  1
# 19973       12     61          2.0        538          4                  0
#
#        mileage  engine  max_power  seats  selling_price  Annualselling_price  \
# 0          359     159        316      5             17                700.0
# 1          322      12        424      5            828                692.0
# 2          238      12        417      5            348                692.0
# 3          404     167        377      5            359                700.0
# 4          456      43        482      5            844                726.0
# ...        ...     ...        ...    ...            ...                  ...
# 19969      472      23        375      5            942                498.0
# 19970      263      25        461      7           1163                700.0
# 19971      414      43         14      5            678                692.0
# 19972      200      82         96      7            157                795.0
# 19973      286      42         51      5            150                806.0
#
#        Prediction
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 19969           1
# 19970           1
# 19971           1
# 19972           1
# 19973           1
#
# [19974 rows x 13 columns]

# %%
dataset.describe(include='all')
# Out:
#             Company         brand   vehicle_age     km_driven     fuel_type  \
# count  19974.000000  19974.000000  19974.000000  19974.000000  19974.000000
# mean      21.680785    145.048914      6.424001   2221.173075      2.457845
# std       10.593036     84.295911      3.092639   1316.326937      1.517765
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       13.000000     70.000000      4.000000   1120.000000      1.000000
# 50%       24.000000    132.000000      6.000000   2268.000000      1.000000
# 75%       24.000000    218.000000      8.000000   3344.000000      4.000000
# max       41.000000    273.000000     14.000000   4514.000000      4.000000
#
#        transmission_type       mileage        engine     max_power  \
# count       19974.000000  19974.000000  19974.000000  19974.000000
# mean            0.802293    330.059477     58.165365    303.543156
# std             0.398280    137.330829     53.195586    159.669664
# min             0.000000      0.000000      0.000000      0.000000
# 25%             1.000000    238.000000     14.000000    147.000000
# 50%             1.000000    342.000000     42.000000    377.000000
# 75%             1.000000    451.000000     82.000000    424.000000
# max             1.000000    561.000000    169.000000    493.000000
#
#               seats  selling_price  Annualselling_price    Prediction
# count  19974.000000   19974.000000         19974.000000  19974.000000
# mean       5.284770     641.980475           663.303294      0.965555
# std        0.896714     317.605501           118.375136      0.182373
# min        0.000000       0.000000            42.000000      0.000000
# 25%        5.000000     402.000000           580.000000      1.000000
# 50%        5.000000     674.000000           700.000000      1.000000
# 75%        5.000000     906.000000           700.000000      1.000000
# max        9.000000    1214.000000           980.000000      1.000000

# %%
dataset.shape
# Out:
# (19974, 13)

# %% [markdown]
# ### Data Modelling

# %% [markdown]
# ###### Splitting of Data

# %%
X=dataset.drop(['Prediction'],axis=1)
y=dataset['Prediction']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42, test_size=0.20)

# %%
X_train.shape
# Out:
# (15979, 12)

# %%
y_train.shape
# Out:
# (15979,)

# %%
X_test.shape
# Out:
# (3995, 12)

# %%
y_test.shape
# Out:
# (3995,)

# %% [markdown]
# ### To find out the best classification model which is accurate :
#             Some of the famous classification models are :
#
#                     1. Logistic Regression Model
#                     2. K-Nearest Neighbor(KNN) Model
#                     3. Random Forest Model
#                     4. Decision Tree Model
#                     5. Support Vector Machine (SVM) Model
#                     6. Gradient Boosting

# %% [markdown]
# #### 1. Logistic Regression Model:

# %%
log_reg = LogisticRegression()
model = log_reg.fit(X_train, y_train)
y_pred=log_reg.predict(X_test)

# %%
print('Accuracy of Logistic Regression model is :',accuracy_score(y_test,y_pred)*100)
print("Precision is :",precision_score(y_test,y_pred,average='weighted'))
print("Recall is : ",recall_score(y_test,y_pred,average='weighted'))
print("F1 Score is :",f1_score(y_test,y_pred,average='weighted'))
# Out:
# Accuracy of Logistic Regression model is : 99.94993742177722
# Precision is : 0.9994993742177722
# Recall is :  0.9994993742177722
# F1 Score is : 0.9994993742177722

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 128,    1],
#        [   1, 3865]], dtype=int64)

# %% [markdown]
# #### 2. K- Nearest Neighbors (KNN) Model:

# %%
model = KNeighborsClassifier(n_neighbors=3) 
model.fit(X_train,y_train)
prediction = model.predict(X_test)

# %%
print('The accuracy of KNN model is : ', accuracy_score(prediction,y_test)*100)
print("Precision is : ",precision_score(prediction,y_test,average = 'weighted'))
print("Recall is : ",recall_score(prediction,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(prediction,y_test,average ='weighted'))
# Out:
# The accuracy of KNN model is :  99.3241551939925
# Precision is :  0.9931746108061273
# Recall is :  0.9932415519399249
# F1 Score is :  0.9932040219252521

# %%
confusion_matrix(prediction,y_test)
# Out:
# array([[ 117,   15],
#        [  12, 3851]], dtype=int64)

# %% [markdown]
# #### 3. Random Forest Model

# %%
rnf = RandomForestClassifier(n_estimators=100)
rnf_model = rnf.fit(X_train, y_train)
rnf_predict = rnf_model.predict(X_test)

# %%
rnf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rnf_predict=rnf.predict(X_test)

# %%
print('Accuracy of Random Forest model is : ',accuracy_score(rnf_predict, y_test) *100)
print("Precision is : ",precision_score(rnf_predict,y_test,average = 'weighted'))
print("Recall is : ",recall_score(rnf_predict,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(rnf_predict,y_test,average ='weighted'))
# Out:
# Accuracy of Random Forest model is :  99.57446808510639
# Precision is :  0.9958494609838633
# Recall is :  0.9957446808510638
# F1 Score is :  0.9957853544692236

# %%
confusion_matrix(y_test,rnf_predict)
# Out:
# array([[ 118,   11],
#        [   6, 3860]], dtype=int64)

# %% [markdown]
# #### 4. Decision Tree Model:

# %%
dtree = DecisionTreeClassifier()
dtree_model = dtree.fit(X_train, y_train)
dtree_predict = dtree.predict(X_test)

# %%
print('Accuracy of Decision Tree model is : ', accuracy_score(dtree_predict, y_test)*100)
print("Precision is : ",precision_score(dtree_predict,y_test,average = 'weighted'))
print("Recall is : ",recall_score(dtree_predict,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(dtree_predict,y_test,average ='weighted'))
# Out:
# Accuracy of Decision Tree model is :  99.37421777221527
# Precision is :  0.9936808635766133
# Recall is :  0.9937421777221527
# F1 Score is :  0.9937074277085668

# %%
confusion_matrix(y_test,dtree_predict)
# Out:
# array([[ 118,   11],
#        [  14, 3852]], dtype=int64)

# %% [markdown]
# #### 5. Support Vector Machine Model:

# %%
from sklearn import svm 
from sklearn.svm import SVC

# %%
svm_linear=SVC(kernel='linear')
svm_linear.fit(X_train,y_train)
pred=svm_linear.predict(X_test)

# %%
print('The accuracy of Support Vector Machine model is: ', accuracy_score(pred,y_test)*100)
print("Precision is : ",precision_score(pred,y_test,average='weighted'))
print("Recall is : ",recall_score(pred,y_test,average='weighted'))
print("F1 Scconfusion_matrix(y_test,pred)ore is : ",f1_score(pred,y_test,average='weighted'))
# Out:
# The accuracy of Support Vector Machine model is:  99.92490613266584
# Precision is :  0.9992472504111614
# Recall is :  0.9992490613266584
# F1 Scconfusion_matrix(y_test,pred)ore is :  0.9992476602048229

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[ 128,    1],
#        [   2, 3864]], dtype=int64)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train , y_train)

#train , test = train_test_split(dataset , test_size=0.2)
#train_X = train.drop(['selling_price'] , axis=1)
#test_x= test.drop(['selling_price'] , axis=1)
#train_y = train.selling_price
#test_y = test.selling_price

pred = lin_reg.predict(X_test)
error = pred- y_test
mse = np.mean(np.square(error))
mae = np.mean(np.abs(error*100/y_test))
print("MSE :" ,mse)
print("MAPE :", mae)
print("Acuracy :", 100 -mae)
# Out:
# MSE : 0.024846959746624025
# MAPE : inf
# Acuracy : -inf
